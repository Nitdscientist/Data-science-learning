# %% [markdown]
# ## Mini Project -6
#
# ### EDA with Loan sanction
#
# #### Name- Nitesh Kumar Batch-4

# %%
# import pandas library
import pandas as pd

# %%
# read excel file and stored in dataframe
df=pd.read_excel("loan_sanction.xlsx",index_col=[0])

# %%
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0         110               360
# ...

# %% [markdown]
# # Q1. Check how many duplicate rows are present

# %%
df.duplicated().sum(axis=0)
# Out:
# 0

# %% [markdown]
# #### Insights:
# There are no any duplicate rows present in our data

# %% [markdown]
# # Q2. If any Duplicates Present, drop those duplicates

# %% [markdown]
# #### Insights:
# There are no any duplicate rows present in our data

# %% [markdown]
# # Q3. Check null values in each column

# %%
df.isnull().sum(axis=0) # check null values in every column row wise
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           10
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# dtype: int64

# %% [markdown]
# #### Insights:
# The dependent column where in 10 null values present

# %% [markdown]
# # Q4. Delete the Rows which are having null values.

# %%
df.dropna(axis=0,inplace=True) # remove row where null values present

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
df.shape # now 10 rows where null values were present that removed now
# Out:
# (357, 12)

# %% [markdown]
# #### Insights:
# Now we get new rows after null values drop

# %% [markdown]
# # Q5. Impute null values with Mode in Gender Column

# %%
# check columns in our dataframe
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
df["Gender"].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
df["Gender"].mode()[0]
# Out:
# 'Male'

# %%
df["Gender"].fillna(df["Gender"].mode()[0],inplace=True)

# %% [markdown]
# # Q6. Impute null values with Mode in Self_Employed Column

# %%
df["Self_Employed"].mode()
# Out:
# 0    No
# Name: Self_Employed, dtype: object

# %%
df["Self_Employed"].mode()[0]
# Out:
# 'No'

# %%
df["Self_Employed"].fillna(df["Self_Employed"].mode()[0],inplace=True)

# %% [markdown]
# # Q7. Impute null values with Median in LoanAmount Column

# %%
df["LoanAmount"].median()
# Out:
# 125.0

# %%
df["LoanAmount"].fillna(df["LoanAmount"].median(),inplace=True)

# %% [markdown]
# # Q8. Top 5 Records

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0         110               360
# 1             3076               1500         126               360
# 2             5000               1800         208               360
# 3             2340               2546         100               360
# 4             3276                  0          78               360
#
#    Credit_History Property_Area
# 0               1         Urban
# 1               1         Urban
# 2               1         Urban
# ...

# %% [markdown]
# # Q9. Export the dataframe in excel.

# %%
df.to_excel("EDA_Loan_sanctioned_miniproject.xlsx")

# %% [markdown]
# # Q10. Number of Rows and Columns in a DataFrame

# %%
df.shape
# Out:
# (357, 12)

# %%
print(f"rows is:",df.shape[0])
print(f"columns is:",df.shape[1])
# Out:
# rows is: 357
# columns is: 12

# %% [markdown]
# # Q11. Print all Column names in a DF

# %%
print(f"All Columns in this Data frame are:",df.columns)
# Out:
# All Columns in this Data frame are: Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %% [markdown]
# # Q12. Generate the descriptive statistics of Numerical variables.

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       357.000000         357.000000  357.000000        357.000000
# mean       4793.602241        1587.098039  136.501401        343.282913
# std        4936.879103        2357.321156   61.503523         64.015457
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2858.000000           0.000000  102.000000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5062.000000        2458.000000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count           357.0
# mean              1.0
# std               0.0
# min               1.0
# 25%               1.0
# 50%               1.0
# 75%               1.0
# max               1.0

# %% [markdown]
# # Q13. Display numeric data type columns in a DF

# %%
df.select_dtypes(include=["int64"])
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0         110               360
# 1               3076               1500         126               360
# 2               5000               1800         208               360
# 3               2340               2546         100               360
# 4               3276                  0          78               360
# ..               ...                ...         ...               ...
# 362             4009               1777         113               360
# 363             4158                709         115               360
# 364             3250               1993         126               360
# 365             5000               2393         158               360
# 366             9200                  0          98               180
#
#      Credit_History
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# ...

# %% [markdown]
# # Q14. Select all data types of columns in a DF except object data type.

# %%
df.select_dtypes(exclude=["object"])
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0         110               360
# 1               3076               1500         126               360
# 2               5000               1800         208               360
# 3               2340               2546         100               360
# 4               3276                  0          78               360
# ..               ...                ...         ...               ...
# 362             4009               1777         113               360
# 363             4158                709         115               360
# 364             3250               1993         126               360
# 365             5000               2393         158               360
# 366             9200                  0          98               180
#
#      Credit_History
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# ...

# %% [markdown]
# # Q15. Extract all the Records where Self_Employed is equal to Yes.

# %%
df["Self_Employed"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df[df["Self_Employed"]=="Yes"]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 5    LP001054    Male     Yes          0  Not Graduate           Yes
# 37   LP001210    Male     Yes          0      Graduate           Yes
# 38   LP001211    Male      No          0      Graduate           Yes
# 49   LP001270    Male     Yes         3+  Not Graduate           Yes
# 54   LP001312    Male     Yes          0  Not Graduate           Yes
# 61   LP001335    Male     Yes          0      Graduate           Yes
# 73   LP001380    Male     Yes          0      Graduate           Yes
# 77   LP001413    Male      No          0      Graduate           Yes
# 90   LP001475    Male     Yes          0      Graduate           Yes
# 110  LP001584  Female      No          0      Graduate           Yes
# 132  LP001728    Male     Yes          1      Graduate           Yes
# 143  LP001791    Male     Yes          0      Graduate           Yes
# 144  LP001794    Male     Yes          2      Graduate           Yes
# ...

# %% [markdown]
# # Q16. Extract all the Records where Property_area is equal to urban in a DF.

# %%
df["Property_Area"].unique()
# Out:
# array(['Urban', 'Semiurban', 'Rural'], dtype=object)

# %%
df[df["Property_Area"]=="Urban"]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001015    Male     Yes          0      Graduate            No
# 1    LP001022    Male     Yes          1      Graduate            No
# 2    LP001031    Male     Yes          2      Graduate            No
# 3    LP001035    Male     Yes          2      Graduate            No
# 4    LP001051    Male      No          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 356  LP002935    Male     Yes          1      Graduate            No
# 357  LP002952    Male      No          0      Graduate            No
# 360  LP002965  Female     Yes          0      Graduate            No
# 362  LP002971    Male     Yes         3+  Not Graduate           Yes
# 363  LP002975    Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # Q17. Print number of unique vaues in Gender column

# %%
print("No. of unique value in Gender Column is:")
print(len(df["Gender"].unique()))
# Out:
# No. of unique value in Gender Column is:
# 2
